# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statsmodels.api as sm

# %%
# Time Series Data Path
ts_data_path = '/Users/prim232/gitrepos/stitches_in_r/R/inst/shinyApp/python_curation/extracted_timeseries/land_regions_ts'

# %%
# Read example time series
pr_data = pd.read_csv(os.path.join(ts_data_path, 'IPCC_land_regions_pr_ACCESS-CM2_timeseries_1980-2099.csv'))

# %%
ssp245_r1i1p1f1 = pr_data[(pr_data['experiment'] == 'ssp245') & (pr_data['ensemble'] == 'r1i1p1f1') & (pr_data['acronym'] =='NWN')]
ssp245_r1i1p1f1
# Out:
#        pr  year         esm experiment  ensemble variable      continent  \
# 25800 NaN  2015  ACCESS-CM2     ssp245  r1i1p1f1       pr  NORTH-AMERICA
# 25843 NaN  2016  ACCESS-CM2     ssp245  r1i1p1f1       pr  NORTH-AMERICA
# 25886 NaN  2017  ACCESS-CM2     ssp245  r1i1p1f1       pr  NORTH-AMERICA
# 25929 NaN  2018  ACCESS-CM2     ssp245  r1i1p1f1       pr  NORTH-AMERICA
# 25972 NaN  2019  ACCESS-CM2     ssp245  r1i1p1f1       pr  NORTH-AMERICA
# ...    ..   ...         ...        ...       ...      ...            ...
# 29240 NaN  2095  ACCESS-CM2     ssp245  r1i1p1f1       pr  NORTH-AMERICA
# 29283 NaN  2096  ACCESS-CM2     ssp245  r1i1p1f1       pr  NORTH-AMERICA
# 29326 NaN  2097  ACCESS-CM2     ssp245  r1i1p1f1       pr  NORTH-AMERICA
# 29369 NaN  2098  ACCESS-CM2     ssp245  r1i1p1f1       pr  NORTH-AMERICA
# 29412 NaN  2099  ACCESS-CM2     ssp245  r1i1p1f1       pr  NORTH-AMERICA
#
#        type               name acronym     value
# 25800  Land  N.W.North-America     NWN  0.000025
# 25843  Land  N.W.North-America     NWN  0.000025
# 25886  Land  N.W.North-America     NWN  0.000025
# 25929  Land  N.W.North-America     NWN  0.000024
# 25972  Land  N.W.North-America     NWN  0.000025
# ...     ...                ...     ...       ...
# 29240  Land  N.W.North-America     NWN  0.000028
# 29283  Land  N.W.North-America     NWN  0.000029
# 29326  Land  N.W.North-America     NWN  0.000027
# 29369  Land  N.W.North-America     NWN  0.000028
# 29412  Land  N.W.North-America     NWN  0.000027
#
# [85 rows x 11 columns]

# %%
output = sm.nonparametric.lowess(ssp245_r1i1p1f1['value'].values, ssp245_r1i1p1f1['year'].values)
smooth_y = list(zip(*output))[1]
iasd = np.std(smooth_y - ssp245_r1i1p1f1['value'].values )

# %%
plt.plot(ssp245_r1i1p1f1.year, smooth_y)
plt.plot(ssp245_r1i1p1f1.year, smooth_y - ssp245_r1i1p1f1['value'].values)
plt.plot(ssp245_r1i1p1f1.year, ssp245_r1i1p1f1['value'])

# %%
def loess(df):
    try:
        output = sm.nonparametric.lowess(df['value'].values, df['year'].values)
        smooth_y = list(zip(*output))[1]
        iasd = np.std(smooth_y - df['value'].values )
        df = df[['type', 'name']].head(1)
        df['iasd'] = iasd
    except IndexError:
        esm = df['esm'][0,:]
        print(f'Index Out of Range for {esm}')
        
    return df

# %%
grouped = pr_data.groupby(
    ['esm', 'experiment', 'ensemble', 'variable', 'acronym']
)
pr_iasd = grouped.apply(loess)
pr_iasd = pr_iasd.reset_index()[['esm', 'experiment', 'ensemble', 'variable', 'type', 'name', 'iasd']]
pr_iasd
# Out:
#              esm  experiment  ensemble variable        type  \
# 0     ACCESS-CM2  historical  r1i1p1f1       pr        Land
# 1     ACCESS-CM2  historical  r1i1p1f1       pr        Land
# 2     ACCESS-CM2  historical  r1i1p1f1       pr  Land-Ocean
# 3     ACCESS-CM2  historical  r1i1p1f1       pr        Land
# 4     ACCESS-CM2  historical  r1i1p1f1       pr        Land
# ...          ...         ...       ...      ...         ...
# 1070  ACCESS-CM2      ssp585  r5i1p1f1       pr        Land
# 1071  ACCESS-CM2      ssp585  r5i1p1f1       pr        Land
# 1072  ACCESS-CM2      ssp585  r5i1p1f1       pr        Land
# 1073  ACCESS-CM2      ssp585  r5i1p1f1       pr        Land
# 1074  ACCESS-CM2      ssp585  r5i1p1f1       pr        Land
#
#                      name          iasd
# 0       Arabian-Peninsula  6.266547e-07
# 1          Central-Africa  2.549411e-06
# 2               Caribbean  6.320920e-06
# 3             C.Australia  3.015601e-06
# 4         C.North-America  2.406804e-06
# ...                   ...           ...
# 1070             W.C.Asia  2.010519e-06
# 1071  West&Central-Europe  2.197986e-06
# 1072      W.North-America  2.840268e-06
# 1073    W.Southern-Africa  1.907002e-06
# 1074            W.Siberia  1.287028e-06
#
# [1075 rows x 7 columns]

# %% [markdown]
# # Read In All Time Series

# %%
dataframes = [pd.read_csv(os.path.join(ts_data_path, file)) for file in os.listdir(ts_data_path)]
full_data = pd.concat(dataframes)
full_data
# Out:
#        tas  year           esm  experiment   ensemble variable      continent  \
# 0      NaN  1980    MRI-ESM2-0  historical  r10i1p1f1      tas  NORTH-AMERICA
# 1      NaN  1980    MRI-ESM2-0  historical  r10i1p1f1      tas  NORTH-AMERICA
# 2      NaN  1980    MRI-ESM2-0  historical  r10i1p1f1      tas  NORTH-AMERICA
# 3      NaN  1980    MRI-ESM2-0  historical  r10i1p1f1      tas  NORTH-AMERICA
# 4      NaN  1980    MRI-ESM2-0  historical  r10i1p1f1      tas  NORTH-AMERICA
# ...    ...   ...           ...         ...        ...      ...            ...
# 16120  NaN  2099  CMCC-CM2-SR5      ssp585   r1i1p1f1       pr        OCEANIA
# 16121  NaN  2099  CMCC-CM2-SR5      ssp585   r1i1p1f1       pr        OCEANIA
# 16122  NaN  2099  CMCC-CM2-SR5      ssp585   r1i1p1f1       pr        OCEANIA
# 16123  NaN  2099  CMCC-CM2-SR5      ssp585   r1i1p1f1       pr        OCEANIA
# 16124  NaN  2099  CMCC-CM2-SR5      ssp585   r1i1p1f1       pr        OCEANIA
#
#        type               name acronym       value  pr  ann_agg
# 0      Land  N.W.North-America     NWN  270.696579 NaN      NaN
# 1      Land  N.E.North-America     NEN  266.334754 NaN      NaN
# 2      Land    W.North-America     WNA  282.077686 NaN      NaN
# 3      Land    C.North-America     CNA  285.535020 NaN      NaN
# 4      Land    E.North-America     ENA  284.469444 NaN      NaN
# ...     ...                ...     ...         ...  ..      ...
# 16120  Land        N.Australia     NAU    0.000038 NaN      NaN
# 16121  Land        C.Australia     CAU    0.000014 NaN      NaN
# 16122  Land        E.Australia     EAU    0.000029 NaN      NaN
# 16123  Land        S.Australia     SAU    0.000015 NaN      NaN
# 16124  Land        New-Zealand      NZ    0.000038 NaN      NaN
#
# [6653175 rows x 13 columns]

# %% [markdown]
# ### Differing Formats
# Most data has value column which holds either the pr or tas value. Some files have a dedicated pr or ann_agg column which holds that value. First we make sure that all data has the form which has the value column.

# %%
semi_full_data_non_nan = full_data[~np.isnan(full_data['value'])]

# %%
pr_data = full_data[np.isnan(full_data['value']) & (~np.isnan(full_data['pr']))]
pr_data['value'] = pr_data['pr']
pr_data
# Out:
# /var/folders/03/82f8dprj20zdn3zkgcd_p1280000gn/T/ipykernel_10731/3726116848.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pr_data['value'] = pr_data['pr']
#         tas  year            esm  experiment   ensemble variable  \
# 0       NaN  1980         MIROC6  historical   r6i1p1f1       pr
# 1       NaN  1981         MIROC6  historical   r6i1p1f1       pr
# 2       NaN  1982         MIROC6  historical   r6i1p1f1       pr
# 3       NaN  1983         MIROC6  historical   r6i1p1f1       pr
# 4       NaN  1984         MIROC6  historical   r6i1p1f1       pr
# ...     ...   ...            ...         ...        ...      ...
# 484175  NaN  2095  ACCESS-ESM1-5      ssp585  r21i1p1f1       pr
# 484176  NaN  2096  ACCESS-ESM1-5      ssp585  r21i1p1f1       pr
# 484177  NaN  2097  ACCESS-ESM1-5      ssp585  r21i1p1f1       pr
# 484178  NaN  2098  ACCESS-ESM1-5      ssp585  r21i1p1f1       pr
# 484179  NaN  2099  ACCESS-ESM1-5      ssp585  r21i1p1f1       pr
#
#             continent  type               name acronym     value        pr  \
# 0       NORTH-AMERICA  Land  N.W.North-America     NWN  0.000024  0.000024
# 1       NORTH-AMERICA  Land  N.W.North-America     NWN  0.000024  0.000024
# 2       NORTH-AMERICA  Land  N.W.North-America     NWN  0.000022  0.000022
# 3       NORTH-AMERICA  Land  N.W.North-America     NWN  0.000023  0.000023
# 4       NORTH-AMERICA  Land  N.W.North-America     NWN  0.000025  0.000025
# ...               ...   ...                ...     ...       ...       ...
# 484175        OCEANIA  Land        New-Zealand      NZ  0.000035  0.000035
# 484176        OCEANIA  Land        New-Zealand      NZ  0.000034  0.000034
# 484177        OCEANIA  Land        New-Zealand      NZ  0.000038  0.000038
# 484178        OCEANIA  Land        New-Zealand      NZ  0.000038  0.000038
# 484179        OCEANIA  Land        New-Zealand      NZ  0.000033  0.000033
#
#         ann_agg
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 484175      NaN
# 484176      NaN
# 484177      NaN
# 484178      NaN
# 484179      NaN
#
# [2603220 rows x 13 columns]

# %%
tas_data = full_data[np.isnan(full_data['value']) & (~np.isnan(full_data['ann_agg']))]
tas_data['value'] = tas_data['ann_agg']
tas_data
# Out:
# /var/folders/03/82f8dprj20zdn3zkgcd_p1280000gn/T/ipykernel_10731/3579803007.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tas_data['value'] = tas_data['ann_agg']
#        tas  year            esm  experiment  ensemble variable      continent  \
# 0      NaN  1980  ACCESS-ESM1-5  historical  r1i1p1f1      tas  NORTH-AMERICA
# 1      NaN  1981  ACCESS-ESM1-5  historical  r1i1p1f1      tas  NORTH-AMERICA
# 2      NaN  1982  ACCESS-ESM1-5  historical  r1i1p1f1      tas  NORTH-AMERICA
# 3      NaN  1983  ACCESS-ESM1-5  historical  r1i1p1f1      tas  NORTH-AMERICA
# 4      NaN  1984  ACCESS-ESM1-5  historical  r1i1p1f1      tas  NORTH-AMERICA
# ...    ...   ...            ...         ...       ...      ...            ...
# 30095  NaN  2095      GFDL-ESM4      ssp119  r1i1p1f1      tas        OCEANIA
# 30096  NaN  2096      GFDL-ESM4      ssp119  r1i1p1f1      tas        OCEANIA
# 30097  NaN  2097      GFDL-ESM4      ssp119  r1i1p1f1      tas        OCEANIA
# 30098  NaN  2098      GFDL-ESM4      ssp119  r1i1p1f1      tas        OCEANIA
# 30099  NaN  2099      GFDL-ESM4      ssp119  r1i1p1f1      tas        OCEANIA
#
#        type               name acronym       value  pr     ann_agg
# 0      Land  N.W.North-America     NWN  269.381756 NaN  269.381756
# 1      Land  N.W.North-America     NWN  269.047394 NaN  269.047394
# 2      Land  N.W.North-America     NWN  268.858411 NaN  268.858411
# 3      Land  N.W.North-America     NWN  268.831337 NaN  268.831337
# 4      Land  N.W.North-America     NWN  269.969551 NaN  269.969551
# ...     ...                ...     ...         ...  ..         ...
# 30095  Land        New-Zealand      NZ  287.475857 NaN  287.475857
# 30096  Land        New-Zealand      NZ  287.519966 NaN  287.519966
# 30097  Land        New-Zealand      NZ  287.910891 NaN  287.910891
# 30098  Land        New-Zealand      NZ  287.492235 NaN  287.492235
# 30099  Land        New-Zealand      NZ  287.654429 NaN  287.654429
#
# [2605370 rows x 13 columns]

# %%
full_data_non_nan = pd.concat([semi_full_data_non_nan, pr_data, tas_data])
full_data_non_nan = full_data_non_nan[['esm', 'experiment', 'ensemble', 'variable', 'continent', 'type', 'name', 'acronym', 'year', 'value']]
full_data_non_nan
# Out:
#               esm  experiment   ensemble variable      continent  type  \
# 0      MRI-ESM2-0  historical  r10i1p1f1      tas  NORTH-AMERICA  Land
# 1      MRI-ESM2-0  historical  r10i1p1f1      tas  NORTH-AMERICA  Land
# 2      MRI-ESM2-0  historical  r10i1p1f1      tas  NORTH-AMERICA  Land
# 3      MRI-ESM2-0  historical  r10i1p1f1      tas  NORTH-AMERICA  Land
# 4      MRI-ESM2-0  historical  r10i1p1f1      tas  NORTH-AMERICA  Land
# ...           ...         ...        ...      ...            ...   ...
# 30095   GFDL-ESM4      ssp119   r1i1p1f1      tas        OCEANIA  Land
# 30096   GFDL-ESM4      ssp119   r1i1p1f1      tas        OCEANIA  Land
# 30097   GFDL-ESM4      ssp119   r1i1p1f1      tas        OCEANIA  Land
# 30098   GFDL-ESM4      ssp119   r1i1p1f1      tas        OCEANIA  Land
# 30099   GFDL-ESM4      ssp119   r1i1p1f1      tas        OCEANIA  Land
#
#                     name acronym  year       value
# 0      N.W.North-America     NWN  1980  270.696579
# 1      N.E.North-America     NEN  1980  266.334754
# 2        W.North-America     WNA  1980  282.077686
# 3        C.North-America     CNA  1980  285.535020
# 4        E.North-America     ENA  1980  284.469444
# ...                  ...     ...   ...         ...
# 30095        New-Zealand      NZ  2095  287.475857
# 30096        New-Zealand      NZ  2096  287.519966
# 30097        New-Zealand      NZ  2097  287.910891
# 30098        New-Zealand      NZ  2098  287.492235
# 30099        New-Zealand      NZ  2099  287.654429
#
# [6653175 rows x 10 columns]

# %% [markdown]
# ### Getting models / variable which has the full time series available

# %%
data_1980 = full_data_non_nan[full_data_non_nan['year'] == 1980].groupby(['esm','variable']).size().reset_index().rename(columns={0:'count'})

# %%
data_2099 = full_data_non_nan[full_data_non_nan['year'] == 2099].groupby(['esm','variable']).size().reset_index().rename(columns={0:'count'})

# %%
avail_data = pd.merge(data_1980, data_2099, how = 'inner', left_on=['esm', 'variable'], right_on=['esm', 'variable'])[['esm', 'variable']]

# %%
full_data_non_nan_full_ts = pd.merge(avail_data, full_data_non_nan, how='left', left_on=['esm', 'variable'], right_on=['esm', 'variable'])

# %%
full_data_non_nan_full_ts
# Out:
#                  esm variable  experiment  ensemble      continent  type  \
# 0         ACCESS-CM2       pr  historical  r1i1p1f1  NORTH-AMERICA  Land
# 1         ACCESS-CM2       pr  historical  r1i1p1f1  NORTH-AMERICA  Land
# 2         ACCESS-CM2       pr  historical  r1i1p1f1  NORTH-AMERICA  Land
# 3         ACCESS-CM2       pr  historical  r1i1p1f1  NORTH-AMERICA  Land
# 4         ACCESS-CM2       pr  historical  r1i1p1f1  NORTH-AMERICA  Land
# ...              ...      ...         ...       ...            ...   ...
# 6408930  UKESM1-0-LL      tas      ssp434  r4i1p1f2        OCEANIA  Land
# 6408931  UKESM1-0-LL      tas      ssp434  r4i1p1f2        OCEANIA  Land
# 6408932  UKESM1-0-LL      tas      ssp434  r4i1p1f2        OCEANIA  Land
# 6408933  UKESM1-0-LL      tas      ssp434  r4i1p1f2        OCEANIA  Land
# 6408934  UKESM1-0-LL      tas      ssp434  r4i1p1f2        OCEANIA  Land
#
#                       name acronym  year       value
# 0        N.W.North-America     NWN  1980    0.000023
# 1        N.E.North-America     NEN  1980    0.000019
# 2          W.North-America     WNA  1980    0.000026
# 3          C.North-America     CNA  1980    0.000031
# 4          E.North-America     ENA  1980    0.000040
# ...                    ...     ...   ...         ...
# 6408930        New-Zealand      NZ  2095  289.699848
# 6408931        New-Zealand      NZ  2096  288.947738
# 6408932        New-Zealand      NZ  2097  289.437685
# 6408933        New-Zealand      NZ  2098  289.438058
# 6408934        New-Zealand      NZ  2099  289.277296
#
# [6408935 rows x 10 columns]

# %%
hist_data = full_data_non_nan_full_ts[full_data_non_nan_full_ts['experiment'] == 'historical']
fut_data = full_data_non_nan_full_ts[full_data_non_nan_full_ts['experiment'] != 'historical']
all_combs = fut_data[['esm', 'experiment', 'variable', 'ensemble', 'acronym']].drop_duplicates()
comb_data = pd.merge(all_combs, hist_data, how='inner', left_on=['esm', 'variable', 'ensemble', 'acronym'], right_on=['esm', 'variable', 'ensemble', 'acronym'])
comb_data
# Out:
#                  esm experiment_x variable   ensemble acronym experiment_y  \
# 0         ACCESS-CM2       ssp126       pr   r1i1p1f1     NWN   historical
# 1         ACCESS-CM2       ssp126       pr   r1i1p1f1     NWN   historical
# 2         ACCESS-CM2       ssp126       pr   r1i1p1f1     NWN   historical
# 3         ACCESS-CM2       ssp126       pr   r1i1p1f1     NWN   historical
# 4         ACCESS-CM2       ssp126       pr   r1i1p1f1     NWN   historical
# ...              ...          ...      ...        ...     ...          ...
# 2259000  UKESM1-0-LL       ssp245      tas  r13i1p1f2      NZ   historical
# 2259001  UKESM1-0-LL       ssp245      tas  r13i1p1f2      NZ   historical
# 2259002  UKESM1-0-LL       ssp245      tas  r13i1p1f2      NZ   historical
# 2259003  UKESM1-0-LL       ssp245      tas  r13i1p1f2      NZ   historical
# 2259004  UKESM1-0-LL       ssp245      tas  r13i1p1f2      NZ   historical
#
#              continent  type               name  year       value
# 0        NORTH-AMERICA  Land  N.W.North-America  1980    0.000023
# 1        NORTH-AMERICA  Land  N.W.North-America  1981    0.000023
# 2        NORTH-AMERICA  Land  N.W.North-America  1982    0.000025
# 3        NORTH-AMERICA  Land  N.W.North-America  1983    0.000023
# 4        NORTH-AMERICA  Land  N.W.North-America  1984    0.000023
# ...                ...   ...                ...   ...         ...
# 2259000        OCEANIA  Land        New-Zealand  2010  286.657503
# 2259001        OCEANIA  Land        New-Zealand  2011  287.447796
# 2259002        OCEANIA  Land        New-Zealand  2012  287.750295
# 2259003        OCEANIA  Land        New-Zealand  2013  287.506973
# 2259004        OCEANIA  Land        New-Zealand  2014  287.082553
#
# [2259005 rows x 11 columns]

# %%
comb_data = comb_data.rename(columns={'experiment_x': 'experiment'})[['esm', 'experiment', 'variable', 'ensemble', 'continent', 'type', 'name', 'acronym', 'year', 'value']]
comb_data
# Out:
#                  esm experiment variable   ensemble      continent  type  \
# 0         ACCESS-CM2     ssp126       pr   r1i1p1f1  NORTH-AMERICA  Land
# 1         ACCESS-CM2     ssp126       pr   r1i1p1f1  NORTH-AMERICA  Land
# 2         ACCESS-CM2     ssp126       pr   r1i1p1f1  NORTH-AMERICA  Land
# 3         ACCESS-CM2     ssp126       pr   r1i1p1f1  NORTH-AMERICA  Land
# 4         ACCESS-CM2     ssp126       pr   r1i1p1f1  NORTH-AMERICA  Land
# ...              ...        ...      ...        ...            ...   ...
# 2259000  UKESM1-0-LL     ssp245      tas  r13i1p1f2        OCEANIA  Land
# 2259001  UKESM1-0-LL     ssp245      tas  r13i1p1f2        OCEANIA  Land
# 2259002  UKESM1-0-LL     ssp245      tas  r13i1p1f2        OCEANIA  Land
# 2259003  UKESM1-0-LL     ssp245      tas  r13i1p1f2        OCEANIA  Land
# 2259004  UKESM1-0-LL     ssp245      tas  r13i1p1f2        OCEANIA  Land
#
#                       name acronym  year       value
# 0        N.W.North-America     NWN  1980    0.000023
# 1        N.W.North-America     NWN  1981    0.000023
# 2        N.W.North-America     NWN  1982    0.000025
# 3        N.W.North-America     NWN  1983    0.000023
# 4        N.W.North-America     NWN  1984    0.000023
# ...                    ...     ...   ...         ...
# 2259000        New-Zealand      NZ  2010  286.657503
# 2259001        New-Zealand      NZ  2011  287.447796
# 2259002        New-Zealand      NZ  2012  287.750295
# 2259003        New-Zealand      NZ  2013  287.506973
# 2259004        New-Zealand      NZ  2014  287.082553
#
# [2259005 rows x 10 columns]

# %%
extended_data = pd.concat([fut_data, comb_data])
extended_data
# Out:
#                  esm variable experiment   ensemble      continent  type  \
# 7525      ACCESS-CM2       pr     ssp126   r1i1p1f1  NORTH-AMERICA  Land
# 7526      ACCESS-CM2       pr     ssp126   r1i1p1f1  NORTH-AMERICA  Land
# 7527      ACCESS-CM2       pr     ssp126   r1i1p1f1  NORTH-AMERICA  Land
# 7528      ACCESS-CM2       pr     ssp126   r1i1p1f1  NORTH-AMERICA  Land
# 7529      ACCESS-CM2       pr     ssp126   r1i1p1f1  NORTH-AMERICA  Land
# ...              ...      ...        ...        ...            ...   ...
# 2259000  UKESM1-0-LL      tas     ssp245  r13i1p1f2        OCEANIA  Land
# 2259001  UKESM1-0-LL      tas     ssp245  r13i1p1f2        OCEANIA  Land
# 2259002  UKESM1-0-LL      tas     ssp245  r13i1p1f2        OCEANIA  Land
# 2259003  UKESM1-0-LL      tas     ssp245  r13i1p1f2        OCEANIA  Land
# 2259004  UKESM1-0-LL      tas     ssp245  r13i1p1f2        OCEANIA  Land
#
#                       name acronym  year       value
# 7525     N.W.North-America     NWN  2015    0.000022
# 7526     N.E.North-America     NEN  2015    0.000019
# 7527       W.North-America     WNA  2015    0.000032
# 7528       C.North-America     CNA  2015    0.000032
# 7529       E.North-America     ENA  2015    0.000043
# ...                    ...     ...   ...         ...
# 2259000        New-Zealand      NZ  2010  286.657503
# 2259001        New-Zealand      NZ  2011  287.447796
# 2259002        New-Zealand      NZ  2012  287.750295
# 2259003        New-Zealand      NZ  2013  287.506973
# 2259004        New-Zealand      NZ  2014  287.082553
#
# [7840190 rows x 10 columns]

# %% [markdown]
# # Apply IASD Calculation

# %%
grouped = extended_data.groupby(
    ['esm', 'experiment', 'ensemble', 'variable', 'acronym']
)
iasd_data = grouped.apply(loess)
iasd_data = iasd_data.reset_index()[['esm', 'experiment', 'ensemble', 'variable', 'type', 'name', 'acronym', 'iasd']]
iasd_data
# Out:
#                esm experiment  ensemble variable        type  \
# 0       ACCESS-CM2     ssp126  r1i1p1f1       pr        Land
# 1       ACCESS-CM2     ssp126  r1i1p1f1       pr        Land
# 2       ACCESS-CM2     ssp126  r1i1p1f1       pr  Land-Ocean
# 3       ACCESS-CM2     ssp126  r1i1p1f1       pr        Land
# 4       ACCESS-CM2     ssp126  r1i1p1f1       pr        Land
# ...            ...        ...       ...      ...         ...
# 63678  UKESM1-0-LL     ssp585  r8i1p1f2      tas        Land
# 63679  UKESM1-0-LL     ssp585  r8i1p1f2      tas        Land
# 63680  UKESM1-0-LL     ssp585  r8i1p1f2      tas        Land
# 63681  UKESM1-0-LL     ssp585  r8i1p1f2      tas        Land
# 63682  UKESM1-0-LL     ssp585  r8i1p1f2      tas        Land
#
#                       name acronym          iasd
# 0        Arabian-Peninsula     ARP  7.643421e-07
# 1           Central-Africa     CAF  3.497989e-06
# 2                Caribbean     CAR  6.144067e-06
# 3              C.Australia     CAU  2.993824e-06
# 4          C.North-America     CNA  3.045247e-06
# ...                    ...     ...           ...
# 63678             W.C.Asia     WCA  4.529993e+00
# 63679  West&Central-Europe     WCE  4.967584e+00
# 63680      W.North-America     WNA  4.754692e+00
# 63681    W.Southern-Africa    WSAF  3.413978e+00
# 63682            W.Siberia     WSB  6.364592e+00
#
# [63683 rows x 8 columns]

# %% [markdown]
# # Getting Value Over Most Recent 20 years, and Anomaly Since Reference Period (1995-2014)
# (and mid-century period)

# %%
grouped = full_data_non_nan_full_ts[(full_data_non_nan_full_ts['year'] >= 1995) & (full_data_non_nan_full_ts['year'] <= 2014)].groupby([
        'esm', 
        'experiment', 
        'ensemble', 
        'variable', 
        'acronym'
])
hist_df = grouped.agg(
        hist_val = pd.NamedAgg(column='value', aggfunc=np.mean)
).reset_index().dropna()

# %%
grouped = full_data_non_nan_full_ts[(full_data_non_nan_full_ts['year'] >= 2080) & (full_data_non_nan_full_ts['year'] <= 2099)].groupby([
        'esm', 
        'experiment', 
        'ensemble', 
        'variable', 
        'acronym'
])
fut_df = grouped.agg(
        end_val = pd.NamedAgg(column='value', aggfunc=np.mean)
).reset_index().dropna()

# %%
grouped = full_data_non_nan_full_ts[(full_data_non_nan_full_ts['year'] >= 2040) & (full_data_non_nan_full_ts['year'] <= 2059)].groupby([
        'esm', 
        'experiment', 
        'ensemble', 
        'variable', 
        'acronym'
])
mid_century = grouped.agg(
        mid_century_val = pd.NamedAgg(column='value', aggfunc=np.mean)
).reset_index().dropna()

# %%
# Future Anomaly
merged_df1 = pd.merge(hist_df, fut_df, how = 'inner', left_on=['esm', 'ensemble', 'variable', 'acronym'], right_on=['esm', 'ensemble', 'variable', 'acronym'])
merged_df1['end_anomaly'] = merged_df1['end_val'] - merged_df1['hist_val']
merged_df1['end_anomaly_pct'] = merged_df1['end_anomaly'] / merged_df1['hist_val']
merged_df1 = merged_df1.rename(columns={'experiment_y': 'experiment'})
merged_df1 = merged_df1[['esm', 'experiment', 'ensemble', 'variable', 'acronym', 'end_val', 'end_anomaly', 'end_anomaly_pct']]

# %%
# Mid-Century Anomaly
merged_df2 = pd.merge(hist_df, mid_century, how = 'inner', left_on=['esm', 'ensemble', 'variable', 'acronym'], right_on=['esm', 'ensemble', 'variable', 'acronym'])
merged_df2['mid_anomaly'] = merged_df2['mid_century_val'] - merged_df2['hist_val']
merged_df2['mid_anomaly_pct'] = merged_df2['mid_anomaly'] / merged_df2['hist_val']
merged_df2 = merged_df2.rename(columns={'experiment_y': 'experiment'})
merged_df2 = merged_df2[['esm', 'experiment', 'ensemble', 'variable', 'acronym', 'mid_century_val', 'mid_anomaly', 'mid_anomaly_pct']]

# %%
# Merge Mean/Anomaly/Pct Data Frames
merged_df = pd.merge(merged_df1, merged_df2, how='inner', left_on=['esm', 'experiment', 'ensemble', 'variable', 'acronym'], right_on=['esm', 'experiment', 'ensemble', 'variable', 'acronym'])

# %%
# Merge with IASD data
final_metric_data = pd.merge(iasd_data, merged_df, how='inner', left_on=['esm', 'experiment', 'ensemble', 'variable', 'acronym'], right_on=['esm', 'experiment', 'ensemble', 'variable', 'acronym'])

# %%
final_metric_data
# Out:
#                esm experiment  ensemble variable        type  \
# 0       ACCESS-CM2     ssp126  r1i1p1f1       pr        Land
# 1       ACCESS-CM2     ssp126  r1i1p1f1       pr        Land
# 2       ACCESS-CM2     ssp126  r1i1p1f1       pr  Land-Ocean
# 3       ACCESS-CM2     ssp126  r1i1p1f1       pr        Land
# 4       ACCESS-CM2     ssp126  r1i1p1f1       pr        Land
# ...            ...        ...       ...      ...         ...
# 62560  UKESM1-0-LL     ssp585  r8i1p1f2      tas        Land
# 62561  UKESM1-0-LL     ssp585  r8i1p1f2      tas        Land
# 62562  UKESM1-0-LL     ssp585  r8i1p1f2      tas        Land
# 62563  UKESM1-0-LL     ssp585  r8i1p1f2      tas        Land
# 62564  UKESM1-0-LL     ssp585  r8i1p1f2      tas        Land
#
#                       name acronym          iasd     end_val   end_anomaly  \
# 0        Arabian-Peninsula     ARP  7.643421e-07    0.000002  4.306991e-07
# 1           Central-Africa     CAF  3.497989e-06    0.000048 -4.965491e-08
# 2                Caribbean     CAR  6.144067e-06    0.000031  2.089845e-07
# 3              C.Australia     CAU  2.993824e-06    0.000011 -1.269868e-06
# 4          C.North-America     CNA  3.045247e-06    0.000032  1.953880e-06
# ...                    ...     ...           ...         ...           ...
# 62560             W.C.Asia     WCA  4.529993e+00  295.272703  7.437846e+00
# 62561  West&Central-Europe     WCE  4.967584e+00  288.723746  7.920913e+00
# 62562      W.North-America     WNA  4.754692e+00  288.707498  7.960485e+00
# 62563    W.Southern-Africa    WSAF  3.413978e+00  299.555257  5.712152e+00
# 62564            W.Siberia     WSB  6.364592e+00  284.381495  1.032120e+01
#
#        end_anomaly_pct  mid_century_val   mid_anomaly  mid_anomaly_pct
# 0             0.339153         0.000002  7.818446e-07         0.615662
# 1            -0.001027         0.000049  1.080502e-06         0.022357
# 2             0.006893         0.000034  3.972086e-06         0.131011
# 3            -0.100986         0.000011 -1.311461e-06        -0.104294
# 4             0.064341         0.000032  1.857811e-06         0.061177
# ...                ...              ...           ...              ...
# 62560         0.025841       291.089772  3.254915e+00         0.011308
# 62561         0.028208       284.514016  3.711183e+00         0.013216
# 62562         0.028355       284.675132  3.928119e+00         0.013992
# 62563         0.019439       296.177679  2.334574e+00         0.007945
# 62564         0.037660       278.397133  4.336842e+00         0.015824
#
# [62565 rows x 14 columns]

# %%
# Save output
metric_output_path = '/Users/prim232/gitrepos/stitches_in_r/R/inst/shinyApp/python_curation/extracted_timeseries/extracted_metrics'
final_metric_data.to_csv(os.path.join(metric_output_path, 'IPCC_land_regions_metrics.csv'), index=False)
